# %% [markdown]
# <h2 align = center> Webscrapping </h2>

# %% [markdown]
# In order to obtain the KPIs needed for the project, the demographic information of the Ciudad Autónoma de Buenos Aires is added.

# %% [markdown]
# #### The libreries are imported

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Extraction

# %% [markdown]
# The URL from which the information is taken is defined.

# %%
url = 'https://es.wikipedia.org/wiki/Buenos_Aires'

# %%
response = requests.get(url)
#content = response.txt

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="html" lang="es-AR">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#    <meta content="width=device-width, initial-scale=1" name="viewport"/>
#    <!-- This site is optimized with the Yoast SEO plugin v21.6 - https://yoast.com/wordpress/plugins/seo/ -->
#    <title>
#     Ciudad Autónoma de Buenos Aires - Censo Nacional de Población, Hogares y Viviendas
#    </title>
#    <link href="https://censo.gob.ar/index.php/datos_definitivos_caba/" rel="canonical">
#     <meta content="es_ES" property="og:locale">
#      <meta content="article" property="og:type"/>
#      <meta content="Ciudad Autónoma de Buenos Aires - Censo Nacional de Población, Hogares y Viviendas" property="og:title"/>
# ...

# %%
enlace = soup.find('a', href='https://censo.gob.ar/wp-content/uploads/2023/11/c2022_caba_est_c1_1.xlsx')
if enlace:
    # Si se encuentra el enlace, puedes acceder al texto y a la URL
    texto_del_enlace = enlace.text
    url_del_enlace = enlace['href']

    print("Texto del enlace:", texto_del_enlace)
    print("URL del enlace:", url_del_enlace)
else:
    print("El enlace no fue encontrado en el contenido HTML.")
# Out:
# Texto del enlace: Ciudad Autónoma de Buenos Aires. Total de población, variación absoluta y variación relativa, por comuna. Años 2010 y 2022
# URL del enlace: https://censo.gob.ar/wp-content/uploads/2023/11/c2022_caba_est_c1_1.xlsx
