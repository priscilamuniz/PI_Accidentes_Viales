# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('homicidios.xlsx', sheet_name='HECHOS')

# %%
sns.countplot(data = df, x = 'HH')
plt.xlabel()
# Out:
# <Axes: xlabel='HH', ylabel='count'>
